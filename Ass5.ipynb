# %%
import sys
# !pip install mlxtend
# Out:
# ...
# WARNING: Ignoring invalid distribution ~treamlit (C:\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\anaconda3\Lib\site-packages)

# %%
import csv
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Use forward slashes to avoid unicode error
path = "C:/Users/Pinak chimurkar/Market_Basket_Optimisation.csv"

data = []
with open(path, newline='', encoding='utf-8') as file:
    reader = csv.reader(file, delimiter=',')
    for row in reader:
        # remove empty cells
        items = [item.strip() for item in row if item.strip() != '']
        if items:
            data.append(items)

print("Total Transactions:", len(data))
print("Example Transaction:", data[0])
# Out:
# Total Transactions: 7501
# Example Transaction: ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']

# %%
te = TransactionEncoder()
te_ary = te.fit_transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("One-hot encoded shape:", df.shape)
df.head()
# Out:
# One-hot encoded shape: (7501, 119)
#    almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0     True               True      False     True        False  False
# 1    False              False      False    False        False  False
# 2    False              False      False    False        False  False
# 3    False              False      False     True        False  False
# 4    False              False      False    False        False  False
#
#    barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# 0           False      False        False       False  ...   False
# 1           False      False        False       False  ...   False
# 2           False      False        False       False  ...   False
# 3           False      False        False       False  ...    True
# 4           False      False        False       False  ...   False
#
#    vegetables mix  water spray  white wine  whole weat flour  \
# ...

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets.sort_values(by='support', ascending=False, inplace=True)

print("Frequent Itemsets Found:", len(frequent_itemsets))
frequent_itemsets.head(10)
# Out:
# Frequent Itemsets Found: 257
#      support             itemsets
# 46  0.238368      (mineral water)
# 19  0.179709               (eggs)
# 63  0.174110          (spaghetti)
# 24  0.170911       (french fries)
# 13  0.163845          (chocolate)
# 32  0.132116          (green tea)
# 45  0.129583               (milk)
# 33  0.098254        (ground beef)
# 30  0.095321  (frozen vegetables)
# 53  0.095054           (pancakes)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules.sort_values(by=['lift', 'confidence'], ascending=False, inplace=True)

print("Rules Generated:", len(rules))
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10)
# Out:
# Rules Generated: 406
#                     antecedents                 consequents   support  \
# 163             (herb & pepper)               (ground beef)  0.015998
# 162               (ground beef)             (herb & pepper)  0.015998
# 134  (spaghetti, mineral water)               (ground beef)  0.017064
# 135               (ground beef)  (spaghetti, mineral water)  0.017064
# 388  (spaghetti, mineral water)                 (olive oil)  0.010265
# 389                 (olive oil)  (spaghetti, mineral water)  0.010265
# 161                  (tomatoes)         (frozen vegetables)  0.016131
# 160         (frozen vegetables)                  (tomatoes)  0.016131
# 145                    (shrimp)         (frozen vegetables)  0.016664
# 144         (frozen vegetables)                    (shrimp)  0.016664
#
#      confidence      lift
# 163    0.323450  3.291994
# 162    0.162822  3.291994
# 134    0.285714  2.907928
# 135    0.173677  2.907928
# 388    0.171875  2.609786
# ...

# %%
frequent_itemsets.to_csv("frequent_itemsets.csv", index=False)
rules.to_csv("association_rules.csv", index=False)
print("Files saved successfully in current directory.")
# Out:
# Files saved successfully in current directory.
